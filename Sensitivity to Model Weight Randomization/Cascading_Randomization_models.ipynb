# %%
# Boilerplate imports.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import PIL.Image
from matplotlib import pylab as P
import torch
import torchvision
from torchvision import models, transforms
from torchvision.models import Inception_V3_Weights
# From our repository.
#import saliency.core as saliency
from PIL import Image
import os

from torch.utils.data import DataLoader, Dataset

# %matplotlib inline

# %% [markdown]
# #Cascading Randomization

# %%
#Load Model
#Change weights of the mixed layers
#truncated normal dist

#According to Adebayo order is:


#11 logits
#10 mixed_7c
#9 mixed_7b
#8 mixed_7a
#7 mixed_6e
#6 mixed_6d
#5 mixed_6c
#4 mixed_6b
#3 mixed_6a
#2 mixed_5d
#1 mixed_5c


#QUESTION
#Am I thinking of this right? Randomize one at a time gaining a randomized layer each trial from 11-1 (top to bottom, read in Adebayo)?
#Randomize each bn or conv weight, there's a few for each aforementioned layer
#Assumption for now is branch pool conv.weight

#Potentially save whole model
#model.load_state_dict('/content/drive/MyDrive/Saliency Map Research 2023/Pneumonia Dataset/Models/inception.pt')

#for name, param in model.named_parameters():
#    if param.requires_grad:
#        print(name)

# %%
##### Specify Device

device = torch.device("cpu")

if torch.cuda.is_available():
   print("Training on GPU")
   device = torch.device("cuda:0")
# Out:
# Training on GPU

# %%
model_orig = torch.load('/content/drive/MyDrive/Saliency Map Research 2023/Models/thorax_inception.pt')
model_orig = model_orig.to(device)
for name,param in model_orig.named_parameters():
        if param.requires_grad == True:
            print("\t",name)

# %%
#Make new model for each weight changed
#Branch pool? conv or bn?

#model_orig = torch.load('/content/drive/MyDrive/Saliency Map Research 2023/Models/pneumonia_inception.pt')
torch.save(model_orig, '/content/drive/MyDrive/Saliency Map Research 2023/Sensitivity/cascading_models/Pneumothorax/model_orig.pt')

#Logits
model_logits = model_orig.to(device)

model_logits.AuxLogits.conv0.conv.weight = torch.nn.parameter.Parameter( model_logits.AuxLogits.conv0.conv.weight * torch.rand(model_logits.AuxLogits.conv0.conv.weight.size()).to(device) )
model_logits.AuxLogits.conv0.bn.weight = torch.nn.parameter.Parameter( model_logits.AuxLogits.conv0.bn.weight * torch.rand(model_logits.AuxLogits.conv0.bn.weight.size()).to(device) )
model_logits.AuxLogits.conv0.bn.bias = torch.nn.parameter.Parameter( model_logits.AuxLogits.conv0.bn.bias * torch.rand(model_logits.AuxLogits.conv0.bn.bias.size()).to(device) )

model_logits.AuxLogits.conv1.conv.weight = torch.nn.parameter.Parameter( model_logits.AuxLogits.conv1.conv.weight * torch.rand(model_logits.AuxLogits.conv1.conv.weight.size()).to(device) )
model_logits.AuxLogits.conv1.bn.weight = torch.nn.parameter.Parameter( model_logits.AuxLogits.conv1.bn.weight * torch.rand(model_logits.AuxLogits.conv1.bn.weight.size()).to(device) )
model_logits.AuxLogits.conv1.bn.bias = torch.nn.parameter.Parameter( model_logits.AuxLogits.conv1.bn.bias * torch.rand(model_logits.AuxLogits.conv1.bn.bias.size()).to(device) )

model_logits.AuxLogits.fc.weight = torch.nn.parameter.Parameter( model_logits.AuxLogits.fc.weight * torch.rand(model_logits.AuxLogits.fc.weight.size()).to(device) )
model_logits.AuxLogits.fc.bias = torch.nn.parameter.Parameter( model_logits.AuxLogits.fc.bias * torch.rand(model_logits.AuxLogits.fc.bias.size()).to(device) )

torch.save(model_orig, '/content/drive/MyDrive/Saliency Map Research 2023/Sensitivity/cascading_models/Pneumothorax/model_logits.pt')

# %%
#Mixed7c
model_7c = model_logits

model_7c.Mixed_7c.branch1x1.conv.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch1x1.conv.weight * torch.rand(model_7c.Mixed_7c.branch1x1.conv.weight.size()).to(device) )
model_7c.Mixed_7c.branch1x1.bn.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch1x1.bn.weight * torch.rand(model_7c.Mixed_7c.branch1x1.bn.weight.size()).to(device) )
model_7c.Mixed_7c.branch1x1.bn.bias = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch1x1.bn.bias * torch.rand(model_7c.Mixed_7c.branch1x1.bn.bias.size()).to(device))

model_7c.Mixed_7c.branch3x3_1.conv.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3_1.conv.weight * torch.rand(model_7c.Mixed_7c.branch3x3_1.conv.weight.size()).to(device) )
model_7c.Mixed_7c.branch3x3_1.bn.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3_1.bn.weight * torch.rand(model_7c.Mixed_7c.branch3x3_1.bn.weight.size()).to(device) )
model_7c.Mixed_7c.branch3x3_1.bn.bias = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3_1.bn.bias * torch.rand(model_7c.Mixed_7c.branch3x3_1.bn.bias.size()).to(device) )

model_7c.Mixed_7c.branch3x3_2a.conv.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3_2a.conv.weight * torch.rand(model_7c.Mixed_7c.branch3x3_2a.conv.weight.size()).to(device) )
model_7c.Mixed_7c.branch3x3_2a.bn.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3_2a.bn.weight * torch.rand(model_7c.Mixed_7c.branch3x3_2a.bn.weight.size()).to(device) )
model_7c.Mixed_7c.branch3x3_2a.bn.bias = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3_2a.bn.bias * torch.rand(model_7c.Mixed_7c.branch3x3_2a.bn.bias.size()).to(device) )

model_7c.Mixed_7c.branch3x3_2b.conv.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3_2b.conv.weight * torch.rand(model_7c.Mixed_7c.branch3x3_2b.conv.weight.size()).to(device) )
model_7c.Mixed_7c.branch3x3_2b.bn.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3_2b.bn.weight * torch.rand(model_7c.Mixed_7c.branch3x3_2b.bn.weight.size()).to(device) )
model_7c.Mixed_7c.branch3x3_2b.bn.bias = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3_2b.bn.bias * torch.rand(model_7c.Mixed_7c.branch3x3_2b.bn.bias.size()).to(device) )

model_7c.Mixed_7c.branch3x3dbl_1.conv.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3dbl_1.conv.weight * torch.rand(model_7c.Mixed_7c.branch3x3dbl_1.conv.weight.size()).to(device) )
model_7c.Mixed_7c.branch3x3dbl_1.bn.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3dbl_1.bn.weight * torch.rand(model_7c.Mixed_7c.branch3x3dbl_1.bn.weight.size()).to(device) )
model_7c.Mixed_7c.branch3x3dbl_1.bn.bias = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3dbl_1.bn.bias * torch.rand(model_7c.Mixed_7c.branch3x3dbl_1.bn.bias.size()).to(device) )

model_7c.Mixed_7c.branch3x3dbl_2.conv.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3dbl_2.conv.weight * torch.rand(model_7c.Mixed_7c.branch3x3dbl_2.conv.weight.size()).to(device) )
model_7c.Mixed_7c.branch3x3dbl_2.bn.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3dbl_2.bn.weight * torch.rand(model_7c.Mixed_7c.branch3x3dbl_2.bn.weight.size()).to(device) )
model_7c.Mixed_7c.branch3x3dbl_2.bn.bias = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3dbl_2.bn.bias * torch.rand(model_7c.Mixed_7c.branch3x3dbl_2.bn.bias.size()).to(device) )

model_7c.Mixed_7c.branch3x3dbl_3a.conv.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3dbl_3a.conv.weight * torch.rand(model_7c.Mixed_7c.branch3x3dbl_3a.conv.weight.size()).to(device) )
model_7c.Mixed_7c.branch3x3dbl_3a.bn.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3dbl_3a.bn.weight * torch.rand(model_7c.Mixed_7c.branch3x3dbl_3a.bn.weight.size()).to(device) )
model_7c.Mixed_7c.branch3x3dbl_3a.bn.bias = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3dbl_3a.bn.bias * torch.rand(model_7c.Mixed_7c.branch3x3dbl_3a.bn.bias.size()).to(device) )

model_7c.Mixed_7c.branch3x3dbl_3b.conv.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3dbl_3b.conv.weight * torch.rand(model_7c.Mixed_7c.branch3x3dbl_3b.conv.weight.size()).to(device) )
model_7c.Mixed_7c.branch3x3dbl_3b.bn.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3dbl_3b.bn.weight * torch.rand(model_7c.Mixed_7c.branch3x3dbl_3b.bn.weight.size()).to(device) )
model_7c.Mixed_7c.branch3x3dbl_3b.bn.bias = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch3x3dbl_3b.bn.bias * torch.rand(model_7c.Mixed_7c.branch3x3dbl_3b.bn.bias.size()).to(device) )

model_7c.Mixed_7c.branch_pool.conv.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch_pool.conv.weight * torch.rand(model_7c.Mixed_7c.branch_pool.conv.weight.size()).to(device) )
model_7c.Mixed_7c.branch_pool.bn.weight = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch_pool.bn.weight * torch.rand(model_7c.Mixed_7c.branch_pool.bn.weight.size()).to(device) )
model_7c.Mixed_7c.branch_pool.bn.bias = torch.nn.parameter.Parameter( model_7c.Mixed_7c.branch_pool.bn.bias * torch.rand(model_7c.Mixed_7c.branch_pool.bn.bias.size()).to(device) )

torch.save(model_7c, '/content/drive/MyDrive/Saliency Map Research 2023/Sensitivity/cascading_models/Pneumothorax/model_7c.pt')

# %%
#Mixed7b
model_7b = model_7c

model_7b.Mixed_7b.branch1x1.conv.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch1x1.conv.weight * torch.rand(model_7b.Mixed_7b.branch1x1.conv.weight.size()).to(device) )
model_7b.Mixed_7b.branch1x1.bn.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch1x1.bn.weight * torch.rand(model_7b.Mixed_7b.branch1x1.bn.weight.size()).to(device) )
model_7b.Mixed_7b.branch1x1.bn.bias = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch1x1.bn.bias * torch.rand(model_7b.Mixed_7b.branch1x1.bn.bias.size()).to(device))

model_7b.Mixed_7b.branch3x3_1.conv.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3_1.conv.weight * torch.rand(model_7b.Mixed_7b.branch3x3_1.conv.weight.size()).to(device) )
model_7b.Mixed_7b.branch3x3_1.bn.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3_1.bn.weight * torch.rand(model_7b.Mixed_7b.branch3x3_1.bn.weight.size()).to(device) )
model_7b.Mixed_7b.branch3x3_1.bn.bias = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3_1.bn.bias * torch.rand(model_7b.Mixed_7b.branch3x3_1.bn.bias.size()).to(device) )

model_7b.Mixed_7b.branch3x3_2a.conv.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3_2a.conv.weight * torch.rand(model_7b.Mixed_7b.branch3x3_2a.conv.weight.size()).to(device) )
model_7b.Mixed_7b.branch3x3_2a.bn.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3_2a.bn.weight * torch.rand(model_7b.Mixed_7b.branch3x3_2a.bn.weight.size()).to(device) )
model_7b.Mixed_7b.branch3x3_2a.bn.bias = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3_2a.bn.bias * torch.rand(model_7b.Mixed_7b.branch3x3_2a.bn.bias.size()).to(device) )

model_7b.Mixed_7b.branch3x3_2b.conv.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3_2b.conv.weight * torch.rand(model_7b.Mixed_7b.branch3x3_2b.conv.weight.size()).to(device) )
model_7b.Mixed_7b.branch3x3_2b.bn.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3_2b.bn.weight * torch.rand(model_7b.Mixed_7b.branch3x3_2b.bn.weight.size()).to(device) )
model_7b.Mixed_7b.branch3x3_2b.bn.bias = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3_2b.bn.bias * torch.rand(model_7b.Mixed_7b.branch3x3_2b.bn.bias.size()).to(device) )

model_7b.Mixed_7b.branch3x3dbl_1.conv.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3dbl_1.conv.weight * torch.rand(model_7b.Mixed_7b.branch3x3dbl_1.conv.weight.size()).to(device) )
model_7b.Mixed_7b.branch3x3dbl_1.bn.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3dbl_1.bn.weight * torch.rand(model_7b.Mixed_7b.branch3x3dbl_1.bn.weight.size()).to(device) )
model_7b.Mixed_7b.branch3x3dbl_1.bn.bias = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3dbl_1.bn.bias * torch.rand(model_7b.Mixed_7b.branch3x3dbl_1.bn.bias.size()).to(device) )

model_7b.Mixed_7b.branch3x3dbl_2.conv.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3dbl_2.conv.weight * torch.rand(model_7b.Mixed_7b.branch3x3dbl_2.conv.weight.size()).to(device) )
model_7b.Mixed_7b.branch3x3dbl_2.bn.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3dbl_2.bn.weight * torch.rand(model_7b.Mixed_7b.branch3x3dbl_2.bn.weight.size()).to(device) )
model_7b.Mixed_7b.branch3x3dbl_2.bn.bias = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3dbl_2.bn.bias * torch.rand(model_7b.Mixed_7b.branch3x3dbl_2.bn.bias.size()).to(device) )

model_7b.Mixed_7b.branch3x3dbl_3a.conv.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3dbl_3a.conv.weight * torch.rand(model_7b.Mixed_7b.branch3x3dbl_3a.conv.weight.size()).to(device) )
model_7b.Mixed_7b.branch3x3dbl_3a.bn.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3dbl_3a.bn.weight * torch.rand(model_7b.Mixed_7b.branch3x3dbl_3a.bn.weight.size()).to(device) )
model_7b.Mixed_7b.branch3x3dbl_3a.bn.bias = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3dbl_3a.bn.bias * torch.rand(model_7b.Mixed_7b.branch3x3dbl_3a.bn.bias.size()).to(device) )

model_7b.Mixed_7b.branch3x3dbl_3b.conv.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3dbl_3b.conv.weight * torch.rand(model_7b.Mixed_7b.branch3x3dbl_3b.conv.weight.size()).to(device) )
model_7b.Mixed_7b.branch3x3dbl_3b.bn.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3dbl_3b.bn.weight * torch.rand(model_7b.Mixed_7b.branch3x3dbl_3b.bn.weight.size()).to(device) )
model_7b.Mixed_7b.branch3x3dbl_3b.bn.bias = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch3x3dbl_3b.bn.bias * torch.rand(model_7b.Mixed_7b.branch3x3dbl_3b.bn.bias.size()).to(device) )

model_7b.Mixed_7b.branch_pool.conv.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch_pool.conv.weight * torch.rand(model_7b.Mixed_7b.branch_pool.conv.weight.size()).to(device) )
model_7b.Mixed_7b.branch_pool.bn.weight = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch_pool.bn.weight * torch.rand(model_7b.Mixed_7b.branch_pool.bn.weight.size()).to(device) )
model_7b.Mixed_7b.branch_pool.bn.bias = torch.nn.parameter.Parameter( model_7b.Mixed_7b.branch_pool.bn.bias * torch.rand(model_7b.Mixed_7b.branch_pool.bn.bias.size()).to(device) )

torch.save(model_7b, '/content/drive/MyDrive/Saliency Map Research 2023/Sensitivity/cascading_models/Pneumothorax/model_7b.pt')

# %%
#Mixed7a
model_7a = model_7b

model_7a.Mixed_7a.branch3x3_1.conv.weight = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch3x3_1.conv.weight * torch.rand(model_7a.Mixed_7a.branch3x3_1.conv.weight.size()).to(device) )
model_7a.Mixed_7a.branch3x3_1.bn.weight = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch3x3_1.bn.weight * torch.rand(model_7a.Mixed_7a.branch3x3_1.bn.weight.size()).to(device) )
model_7a.Mixed_7a.branch3x3_1.bn.bias = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch3x3_1.bn.bias * torch.rand(model_7a.Mixed_7a.branch3x3_1.bn.bias.size()).to(device) )

model_7a.Mixed_7a.branch3x3_2.conv.weight = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch3x3_2.conv.weight * torch.rand(model_7a.Mixed_7a.branch3x3_2.conv.weight.size()).to(device) )
model_7a.Mixed_7a.branch3x3_2.bn.weight = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch3x3_2.bn.weight * torch.rand(model_7a.Mixed_7a.branch3x3_2.bn.weight.size()).to(device) )
model_7a.Mixed_7a.branch3x3_2.bn.bias = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch3x3_2.bn.bias * torch.rand(model_7a.Mixed_7a.branch3x3_2.bn.bias.size()).to(device) )

model_7a.Mixed_7a.branch7x7x3_1.conv.weight = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch7x7x3_1.conv.weight * torch.rand(model_7a.Mixed_7a.branch7x7x3_1.conv.weight.size()).to(device) )
model_7a.Mixed_7a.branch7x7x3_1.bn.weight = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch7x7x3_1.bn.weight * torch.rand(model_7a.Mixed_7a.branch7x7x3_1.bn.weight.size()).to(device) )
model_7a.Mixed_7a.branch7x7x3_1.bn.bias = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch7x7x3_1.bn.bias * torch.rand(model_7a.Mixed_7a.branch7x7x3_1.bn.bias.size()).to(device) )

model_7a.Mixed_7a.branch7x7x3_2.conv.weight = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch7x7x3_2.conv.weight * torch.rand(model_7a.Mixed_7a.branch7x7x3_2.conv.weight.size()).to(device) )
model_7a.Mixed_7a.branch7x7x3_2.bn.weight = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch7x7x3_2.bn.weight * torch.rand(model_7a.Mixed_7a.branch7x7x3_2.bn.weight.size()).to(device) )
model_7a.Mixed_7a.branch7x7x3_2.bn.bias = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch7x7x3_2.bn.bias * torch.rand(model_7a.Mixed_7a.branch7x7x3_2.bn.bias.size()).to(device) )

model_7a.Mixed_7a.branch7x7x3_3.conv.weight = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch7x7x3_3.conv.weight * torch.rand(model_7a.Mixed_7a.branch7x7x3_3.conv.weight.size()).to(device) )
model_7a.Mixed_7a.branch7x7x3_3.bn.weight = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch7x7x3_3.bn.weight * torch.rand(model_7a.Mixed_7a.branch7x7x3_3.bn.weight.size()).to(device) )
model_7a.Mixed_7a.branch7x7x3_3.bn.bias = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch7x7x3_3.bn.bias * torch.rand(model_7a.Mixed_7a.branch7x7x3_3.bn.bias.size()).to(device) )

model_7a.Mixed_7a.branch7x7x3_4.conv.weight = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch7x7x3_4.conv.weight * torch.rand(model_7a.Mixed_7a.branch7x7x3_4.conv.weight.size()).to(device) )
model_7a.Mixed_7a.branch7x7x3_4.bn.weight = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch7x7x3_4.bn.weight * torch.rand(model_7a.Mixed_7a.branch7x7x3_4.bn.weight.size()).to(device) )
model_7a.Mixed_7a.branch7x7x3_4.bn.bias = torch.nn.parameter.Parameter( model_7a.Mixed_7a.branch7x7x3_4.bn.bias * torch.rand(model_7a.Mixed_7a.branch7x7x3_4.bn.bias.size()).to(device) )

torch.save(model_7a, '/content/drive/MyDrive/Saliency Map Research 2023/Sensitivity/cascading_models/Pneumothorax/model_7a.pt')

# %%
#Mixed6e
model_6e = model_7a

model_6e.Mixed_6e.branch1x1.conv.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch1x1.conv.weight * torch.rand(model_6e.Mixed_6e.branch1x1.conv.weight.size()).to(device) )
model_6e.Mixed_6e.branch1x1.bn.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch1x1.bn.weight * torch.rand(model_6e.Mixed_6e.branch1x1.bn.weight.size()).to(device) )
model_6e.Mixed_6e.branch1x1.bn.bias = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch1x1.bn.bias * torch.rand(model_6e.Mixed_6e.branch1x1.bn.bias.size()).to(device))

model_6e.Mixed_6e.branch7x7_1.conv.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7_1.conv.weight * torch.rand(model_6e.Mixed_6e.branch7x7_1.conv.weight.size()).to(device) )
model_6e.Mixed_6e.branch7x7_1.bn.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7_1.bn.weight * torch.rand(model_6e.Mixed_6e.branch7x7_1.bn.weight.size()).to(device) )
model_6e.Mixed_6e.branch7x7_1.bn.bias = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7_1.bn.bias * torch.rand(model_6e.Mixed_6e.branch7x7_1.bn.bias.size()).to(device))

model_6e.Mixed_6e.branch7x7_2.conv.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7_2.conv.weight * torch.rand(model_6e.Mixed_6e.branch7x7_2.conv.weight.size()).to(device) )
model_6e.Mixed_6e.branch7x7_2.bn.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7_2.bn.weight * torch.rand(model_6e.Mixed_6e.branch7x7_2.bn.weight.size()).to(device) )
model_6e.Mixed_6e.branch7x7_2.bn.bias = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7_2.bn.bias * torch.rand(model_6e.Mixed_6e.branch7x7_2.bn.bias.size()).to(device))

model_6e.Mixed_6e.branch7x7_3.conv.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7_3.conv.weight * torch.rand(model_6e.Mixed_6e.branch7x7_3.conv.weight.size()).to(device) )
model_6e.Mixed_6e.branch7x7_3.bn.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7_3.bn.weight * torch.rand(model_6e.Mixed_6e.branch7x7_3.bn.weight.size()).to(device) )
model_6e.Mixed_6e.branch7x7_3.bn.bias = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7_3.bn.bias * torch.rand(model_6e.Mixed_6e.branch7x7_3.bn.bias.size()).to(device))

model_6e.Mixed_6e.branch7x7dbl_1.conv.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7dbl_1.conv.weight * torch.rand(model_6e.Mixed_6e.branch7x7dbl_1.conv.weight.size()).to(device) )
model_6e.Mixed_6e.branch7x7dbl_1.bn.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7dbl_1.bn.weight * torch.rand(model_6e.Mixed_6e.branch7x7dbl_1.bn.weight.size()).to(device) )
model_6e.Mixed_6e.branch7x7dbl_1.bn.bias = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7dbl_1.bn.bias * torch.rand(model_6e.Mixed_6e.branch7x7dbl_1.bn.bias.size()).to(device))

model_6e.Mixed_6e.branch7x7dbl_2.conv.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7dbl_2.conv.weight * torch.rand(model_6e.Mixed_6e.branch7x7dbl_2.conv.weight.size()).to(device) )
model_6e.Mixed_6e.branch7x7dbl_2.bn.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7dbl_2.bn.weight * torch.rand(model_6e.Mixed_6e.branch7x7dbl_2.bn.weight.size()).to(device) )
model_6e.Mixed_6e.branch7x7dbl_2.bn.bias = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7dbl_2.bn.bias * torch.rand(model_6e.Mixed_6e.branch7x7dbl_2.bn.bias.size()).to(device))

model_6e.Mixed_6e.branch7x7dbl_3.conv.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7dbl_3.conv.weight * torch.rand(model_6e.Mixed_6e.branch7x7dbl_3.conv.weight.size()).to(device) )
model_6e.Mixed_6e.branch7x7dbl_3.bn.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7dbl_3.bn.weight * torch.rand(model_6e.Mixed_6e.branch7x7dbl_3.bn.weight.size()).to(device) )
model_6e.Mixed_6e.branch7x7dbl_3.bn.bias = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7dbl_3.bn.bias * torch.rand(model_6e.Mixed_6e.branch7x7dbl_3.bn.bias.size()).to(device))

model_6e.Mixed_6e.branch7x7dbl_4.conv.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7dbl_4.conv.weight * torch.rand(model_6e.Mixed_6e.branch7x7dbl_4.conv.weight.size()).to(device) )
model_6e.Mixed_6e.branch7x7dbl_4.bn.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7dbl_4.bn.weight * torch.rand(model_6e.Mixed_6e.branch7x7dbl_4.bn.weight.size()).to(device) )
model_6e.Mixed_6e.branch7x7dbl_4.bn.bias = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7dbl_4.bn.bias * torch.rand(model_6e.Mixed_6e.branch7x7dbl_4.bn.bias.size()).to(device))

model_6e.Mixed_6e.branch7x7dbl_5.conv.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7dbl_5.conv.weight * torch.rand(model_6e.Mixed_6e.branch7x7dbl_5.conv.weight.size()).to(device) )
model_6e.Mixed_6e.branch7x7dbl_5.bn.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7dbl_5.bn.weight * torch.rand(model_6e.Mixed_6e.branch7x7dbl_5.bn.weight.size()).to(device) )
model_6e.Mixed_6e.branch7x7dbl_5.bn.bias = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch7x7dbl_5.bn.bias * torch.rand(model_6e.Mixed_6e.branch7x7dbl_5.bn.bias.size()).to(device))

model_6e.Mixed_6e.branch_pool.conv.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch_pool.conv.weight * torch.rand(model_6e.Mixed_6e.branch_pool.conv.weight.size()) .to(device))
model_6e.Mixed_6e.branch_pool.bn.weight = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch_pool.bn.weight * torch.rand(model_6e.Mixed_6e.branch_pool.bn.weight.size()).to(device) )
model_6e.Mixed_6e.branch_pool.bn.bias = torch.nn.parameter.Parameter( model_6e.Mixed_6e.branch_pool.bn.bias * torch.rand(model_6e.Mixed_6e.branch_pool.bn.bias.size()).to(device) )

torch.save(model_6e, '/content/drive/MyDrive/Saliency Map Research 2023/Sensitivity/cascading_models/Pneumothorax/model_6e.pt')

# %%
#Mixed6d
model_6d = model_6e

model_6d.Mixed_6d.branch1x1.conv.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch1x1.conv.weight * torch.rand(model_6d.Mixed_6d.branch1x1.conv.weight.size()).to(device) )
model_6d.Mixed_6d.branch1x1.bn.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch1x1.bn.weight * torch.rand(model_6d.Mixed_6d.branch1x1.bn.weight.size()).to(device) )
model_6d.Mixed_6d.branch1x1.bn.bias = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch1x1.bn.bias * torch.rand(model_6d.Mixed_6d.branch1x1.bn.bias.size()).to(device))

model_6d.Mixed_6d.branch7x7_1.conv.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7_1.conv.weight * torch.rand(model_6d.Mixed_6d.branch7x7_1.conv.weight.size()).to(device) )
model_6d.Mixed_6d.branch7x7_1.bn.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7_1.bn.weight * torch.rand(model_6d.Mixed_6d.branch7x7_1.bn.weight.size()).to(device) )
model_6d.Mixed_6d.branch7x7_1.bn.bias = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7_1.bn.bias * torch.rand(model_6d.Mixed_6d.branch7x7_1.bn.bias.size()).to(device))

model_6d.Mixed_6d.branch7x7_2.conv.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7_2.conv.weight * torch.rand(model_6d.Mixed_6d.branch7x7_2.conv.weight.size()).to(device) )
model_6d.Mixed_6d.branch7x7_2.bn.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7_2.bn.weight * torch.rand(model_6d.Mixed_6d.branch7x7_2.bn.weight.size()).to(device) )
model_6d.Mixed_6d.branch7x7_2.bn.bias = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7_2.bn.bias * torch.rand(model_6d.Mixed_6d.branch7x7_2.bn.bias.size()).to(device))

model_6d.Mixed_6d.branch7x7_3.conv.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7_3.conv.weight * torch.rand(model_6d.Mixed_6d.branch7x7_3.conv.weight.size()).to(device) )
model_6d.Mixed_6d.branch7x7_3.bn.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7_3.bn.weight * torch.rand(model_6d.Mixed_6d.branch7x7_3.bn.weight.size()).to(device) )
model_6d.Mixed_6d.branch7x7_3.bn.bias = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7_3.bn.bias * torch.rand(model_6d.Mixed_6d.branch7x7_3.bn.bias.size()).to(device))

model_6d.Mixed_6d.branch7x7dbl_1.conv.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7dbl_1.conv.weight * torch.rand(model_6d.Mixed_6d.branch7x7dbl_1.conv.weight.size()).to(device) )
model_6d.Mixed_6d.branch7x7dbl_1.bn.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7dbl_1.bn.weight * torch.rand(model_6d.Mixed_6d.branch7x7dbl_1.bn.weight.size()).to(device) )
model_6d.Mixed_6d.branch7x7dbl_1.bn.bias = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7dbl_1.bn.bias * torch.rand(model_6d.Mixed_6d.branch7x7dbl_1.bn.bias.size()).to(device))

model_6d.Mixed_6d.branch7x7dbl_2.conv.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7dbl_2.conv.weight * torch.rand(model_6d.Mixed_6d.branch7x7dbl_2.conv.weight.size()).to(device) )
model_6d.Mixed_6d.branch7x7dbl_2.bn.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7dbl_2.bn.weight * torch.rand(model_6d.Mixed_6d.branch7x7dbl_2.bn.weight.size()).to(device) )
model_6d.Mixed_6d.branch7x7dbl_2.bn.bias = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7dbl_2.bn.bias * torch.rand(model_6d.Mixed_6d.branch7x7dbl_2.bn.bias.size()).to(device))

model_6d.Mixed_6d.branch7x7dbl_3.conv.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7dbl_3.conv.weight * torch.rand(model_6d.Mixed_6d.branch7x7dbl_3.conv.weight.size()).to(device) )
model_6d.Mixed_6d.branch7x7dbl_3.bn.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7dbl_3.bn.weight * torch.rand(model_6d.Mixed_6d.branch7x7dbl_3.bn.weight.size()).to(device) )
model_6d.Mixed_6d.branch7x7dbl_3.bn.bias = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7dbl_3.bn.bias * torch.rand(model_6d.Mixed_6d.branch7x7dbl_3.bn.bias.size()).to(device))

model_6d.Mixed_6d.branch7x7dbl_4.conv.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7dbl_4.conv.weight * torch.rand(model_6d.Mixed_6d.branch7x7dbl_4.conv.weight.size()).to(device) )
model_6d.Mixed_6d.branch7x7dbl_4.bn.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7dbl_4.bn.weight * torch.rand(model_6d.Mixed_6d.branch7x7dbl_4.bn.weight.size()).to(device) )
model_6d.Mixed_6d.branch7x7dbl_4.bn.bias = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7dbl_4.bn.bias * torch.rand(model_6d.Mixed_6d.branch7x7dbl_4.bn.bias.size()).to(device))

model_6d.Mixed_6d.branch7x7dbl_5.conv.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7dbl_5.conv.weight * torch.rand(model_6d.Mixed_6d.branch7x7dbl_5.conv.weight.size()).to(device) )
model_6d.Mixed_6d.branch7x7dbl_5.bn.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7dbl_5.bn.weight * torch.rand(model_6d.Mixed_6d.branch7x7dbl_5.bn.weight.size()).to(device) )
model_6d.Mixed_6d.branch7x7dbl_5.bn.bias = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch7x7dbl_5.bn.bias * torch.rand(model_6d.Mixed_6d.branch7x7dbl_5.bn.bias.size()).to(device))

model_6d.Mixed_6d.branch_pool.conv.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch_pool.conv.weight * torch.rand(model_6d.Mixed_6d.branch_pool.conv.weight.size()) .to(device))
model_6d.Mixed_6d.branch_pool.bn.weight = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch_pool.bn.weight * torch.rand(model_6d.Mixed_6d.branch_pool.bn.weight.size()).to(device) )
model_6d.Mixed_6d.branch_pool.bn.bias = torch.nn.parameter.Parameter( model_6d.Mixed_6d.branch_pool.bn.bias * torch.rand(model_6d.Mixed_6d.branch_pool.bn.bias.size()).to(device) )

torch.save(model_6d, '/content/drive/MyDrive/Saliency Map Research 2023/Sensitivity/cascading_models/Pneumothorax/model_6d.pt')

# %%
#Mixed6c
model_6c = model_6d

model_6c.Mixed_6c.branch1x1.conv.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch1x1.conv.weight * torch.rand(model_6c.Mixed_6c.branch1x1.conv.weight.size()).to(device) )
model_6c.Mixed_6c.branch1x1.bn.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch1x1.bn.weight * torch.rand(model_6c.Mixed_6c.branch1x1.bn.weight.size()).to(device) )
model_6c.Mixed_6c.branch1x1.bn.bias = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch1x1.bn.bias * torch.rand(model_6c.Mixed_6c.branch1x1.bn.bias.size()).to(device))

model_6c.Mixed_6c.branch7x7_1.conv.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7_1.conv.weight * torch.rand(model_6c.Mixed_6c.branch7x7_1.conv.weight.size()).to(device) )
model_6c.Mixed_6c.branch7x7_1.bn.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7_1.bn.weight * torch.rand(model_6c.Mixed_6c.branch7x7_1.bn.weight.size()).to(device) )
model_6c.Mixed_6c.branch7x7_1.bn.bias = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7_1.bn.bias * torch.rand(model_6c.Mixed_6c.branch7x7_1.bn.bias.size()).to(device))

model_6c.Mixed_6c.branch7x7_2.conv.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7_2.conv.weight * torch.rand(model_6c.Mixed_6c.branch7x7_2.conv.weight.size()).to(device) )
model_6c.Mixed_6c.branch7x7_2.bn.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7_2.bn.weight * torch.rand(model_6c.Mixed_6c.branch7x7_2.bn.weight.size()).to(device) )
model_6c.Mixed_6c.branch7x7_2.bn.bias = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7_2.bn.bias * torch.rand(model_6c.Mixed_6c.branch7x7_2.bn.bias.size()).to(device))

model_6c.Mixed_6c.branch7x7_3.conv.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7_3.conv.weight * torch.rand(model_6c.Mixed_6c.branch7x7_3.conv.weight.size()).to(device) )
model_6c.Mixed_6c.branch7x7_3.bn.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7_3.bn.weight * torch.rand(model_6c.Mixed_6c.branch7x7_3.bn.weight.size()).to(device) )
model_6c.Mixed_6c.branch7x7_3.bn.bias = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7_3.bn.bias * torch.rand(model_6c.Mixed_6c.branch7x7_3.bn.bias.size()).to(device))

model_6c.Mixed_6c.branch7x7dbl_1.conv.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7dbl_1.conv.weight * torch.rand(model_6c.Mixed_6c.branch7x7dbl_1.conv.weight.size()).to(device) )
model_6c.Mixed_6c.branch7x7dbl_1.bn.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7dbl_1.bn.weight * torch.rand(model_6c.Mixed_6c.branch7x7dbl_1.bn.weight.size()).to(device) )
model_6c.Mixed_6c.branch7x7dbl_1.bn.bias = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7dbl_1.bn.bias * torch.rand(model_6c.Mixed_6c.branch7x7dbl_1.bn.bias.size()).to(device))

model_6c.Mixed_6c.branch7x7dbl_2.conv.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7dbl_2.conv.weight * torch.rand(model_6c.Mixed_6c.branch7x7dbl_2.conv.weight.size()).to(device) )
model_6c.Mixed_6c.branch7x7dbl_2.bn.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7dbl_2.bn.weight * torch.rand(model_6c.Mixed_6c.branch7x7dbl_2.bn.weight.size()).to(device) )
model_6c.Mixed_6c.branch7x7dbl_2.bn.bias = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7dbl_2.bn.bias * torch.rand(model_6c.Mixed_6c.branch7x7dbl_2.bn.bias.size()).to(device))

model_6c.Mixed_6c.branch7x7dbl_3.conv.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7dbl_3.conv.weight * torch.rand(model_6c.Mixed_6c.branch7x7dbl_3.conv.weight.size()).to(device) )
model_6c.Mixed_6c.branch7x7dbl_3.bn.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7dbl_3.bn.weight * torch.rand(model_6c.Mixed_6c.branch7x7dbl_3.bn.weight.size()).to(device) )
model_6c.Mixed_6c.branch7x7dbl_3.bn.bias = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7dbl_3.bn.bias * torch.rand(model_6c.Mixed_6c.branch7x7dbl_3.bn.bias.size()).to(device))

model_6c.Mixed_6c.branch7x7dbl_4.conv.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7dbl_4.conv.weight * torch.rand(model_6c.Mixed_6c.branch7x7dbl_4.conv.weight.size()).to(device) )
model_6c.Mixed_6c.branch7x7dbl_4.bn.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7dbl_4.bn.weight * torch.rand(model_6c.Mixed_6c.branch7x7dbl_4.bn.weight.size()).to(device) )
model_6c.Mixed_6c.branch7x7dbl_4.bn.bias = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7dbl_4.bn.bias * torch.rand(model_6c.Mixed_6c.branch7x7dbl_4.bn.bias.size()).to(device))

model_6c.Mixed_6c.branch7x7dbl_5.conv.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7dbl_5.conv.weight * torch.rand(model_6c.Mixed_6c.branch7x7dbl_5.conv.weight.size()).to(device) )
model_6c.Mixed_6c.branch7x7dbl_5.bn.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7dbl_5.bn.weight * torch.rand(model_6c.Mixed_6c.branch7x7dbl_5.bn.weight.size()).to(device) )
model_6c.Mixed_6c.branch7x7dbl_5.bn.bias = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch7x7dbl_5.bn.bias * torch.rand(model_6c.Mixed_6c.branch7x7dbl_5.bn.bias.size()).to(device))

model_6c.Mixed_6c.branch_pool.conv.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch_pool.conv.weight * torch.rand(model_6c.Mixed_6c.branch_pool.conv.weight.size()) .to(device))
model_6c.Mixed_6c.branch_pool.bn.weight = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch_pool.bn.weight * torch.rand(model_6c.Mixed_6c.branch_pool.bn.weight.size()).to(device) )
model_6c.Mixed_6c.branch_pool.bn.bias = torch.nn.parameter.Parameter( model_6c.Mixed_6c.branch_pool.bn.bias * torch.rand(model_6c.Mixed_6c.branch_pool.bn.bias.size()).to(device) )

torch.save(model_6c, '/content/drive/MyDrive/Saliency Map Research 2023/Sensitivity/cascading_models/Pneumothorax/model_6c.pt')

# %%
#Mixed6b
model_6b = model_6c

model_6b.Mixed_6b.branch1x1.conv.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch1x1.conv.weight * torch.rand(model_6b.Mixed_6b.branch1x1.conv.weight.size()).to(device) )
model_6b.Mixed_6b.branch1x1.bn.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch1x1.bn.weight * torch.rand(model_6b.Mixed_6b.branch1x1.bn.weight.size()).to(device) )
model_6b.Mixed_6b.branch1x1.bn.bias = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch1x1.bn.bias * torch.rand(model_6b.Mixed_6b.branch1x1.bn.bias.size()).to(device))

model_6b.Mixed_6b.branch7x7_1.conv.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7_1.conv.weight * torch.rand(model_6b.Mixed_6b.branch7x7_1.conv.weight.size()).to(device) )
model_6b.Mixed_6b.branch7x7_1.bn.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7_1.bn.weight * torch.rand(model_6b.Mixed_6b.branch7x7_1.bn.weight.size()).to(device) )
model_6b.Mixed_6b.branch7x7_1.bn.bias = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7_1.bn.bias * torch.rand(model_6b.Mixed_6b.branch7x7_1.bn.bias.size()).to(device))

model_6b.Mixed_6b.branch7x7_2.conv.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7_2.conv.weight * torch.rand(model_6b.Mixed_6b.branch7x7_2.conv.weight.size()).to(device) )
model_6b.Mixed_6b.branch7x7_2.bn.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7_2.bn.weight * torch.rand(model_6b.Mixed_6b.branch7x7_2.bn.weight.size()).to(device) )
model_6b.Mixed_6b.branch7x7_2.bn.bias = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7_2.bn.bias * torch.rand(model_6b.Mixed_6b.branch7x7_2.bn.bias.size()).to(device))

model_6b.Mixed_6b.branch7x7_3.conv.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7_3.conv.weight * torch.rand(model_6b.Mixed_6b.branch7x7_3.conv.weight.size()).to(device) )
model_6b.Mixed_6b.branch7x7_3.bn.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7_3.bn.weight * torch.rand(model_6b.Mixed_6b.branch7x7_3.bn.weight.size()).to(device) )
model_6b.Mixed_6b.branch7x7_3.bn.bias = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7_3.bn.bias * torch.rand(model_6b.Mixed_6b.branch7x7_3.bn.bias.size()).to(device))

model_6b.Mixed_6b.branch7x7dbl_1.conv.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7dbl_1.conv.weight * torch.rand(model_6b.Mixed_6b.branch7x7dbl_1.conv.weight.size()).to(device) )
model_6b.Mixed_6b.branch7x7dbl_1.bn.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7dbl_1.bn.weight * torch.rand(model_6b.Mixed_6b.branch7x7dbl_1.bn.weight.size()).to(device) )
model_6b.Mixed_6b.branch7x7dbl_1.bn.bias = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7dbl_1.bn.bias * torch.rand(model_6b.Mixed_6b.branch7x7dbl_1.bn.bias.size()).to(device))

model_6b.Mixed_6b.branch7x7dbl_2.conv.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7dbl_2.conv.weight * torch.rand(model_6b.Mixed_6b.branch7x7dbl_2.conv.weight.size()).to(device) )
model_6b.Mixed_6b.branch7x7dbl_2.bn.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7dbl_2.bn.weight * torch.rand(model_6b.Mixed_6b.branch7x7dbl_2.bn.weight.size()).to(device) )
model_6b.Mixed_6b.branch7x7dbl_2.bn.bias = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7dbl_2.bn.bias * torch.rand(model_6b.Mixed_6b.branch7x7dbl_2.bn.bias.size()).to(device))

model_6b.Mixed_6b.branch7x7dbl_3.conv.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7dbl_3.conv.weight * torch.rand(model_6b.Mixed_6b.branch7x7dbl_3.conv.weight.size()).to(device) )
model_6b.Mixed_6b.branch7x7dbl_3.bn.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7dbl_3.bn.weight * torch.rand(model_6b.Mixed_6b.branch7x7dbl_3.bn.weight.size()).to(device) )
model_6b.Mixed_6b.branch7x7dbl_3.bn.bias = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7dbl_3.bn.bias * torch.rand(model_6b.Mixed_6b.branch7x7dbl_3.bn.bias.size()).to(device))

model_6b.Mixed_6b.branch7x7dbl_4.conv.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7dbl_4.conv.weight * torch.rand(model_6b.Mixed_6b.branch7x7dbl_4.conv.weight.size()).to(device) )
model_6b.Mixed_6b.branch7x7dbl_4.bn.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7dbl_4.bn.weight * torch.rand(model_6b.Mixed_6b.branch7x7dbl_4.bn.weight.size()).to(device) )
model_6b.Mixed_6b.branch7x7dbl_4.bn.bias = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7dbl_4.bn.bias * torch.rand(model_6b.Mixed_6b.branch7x7dbl_4.bn.bias.size()).to(device))

model_6b.Mixed_6b.branch7x7dbl_5.conv.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7dbl_5.conv.weight * torch.rand(model_6b.Mixed_6b.branch7x7dbl_5.conv.weight.size()).to(device) )
model_6b.Mixed_6b.branch7x7dbl_5.bn.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7dbl_5.bn.weight * torch.rand(model_6b.Mixed_6b.branch7x7dbl_5.bn.weight.size()).to(device) )
model_6b.Mixed_6b.branch7x7dbl_5.bn.bias = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch7x7dbl_5.bn.bias * torch.rand(model_6b.Mixed_6b.branch7x7dbl_5.bn.bias.size()).to(device))

model_6b.Mixed_6b.branch_pool.conv.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch_pool.conv.weight * torch.rand(model_6b.Mixed_6b.branch_pool.conv.weight.size()) .to(device))
model_6b.Mixed_6b.branch_pool.bn.weight = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch_pool.bn.weight * torch.rand(model_6b.Mixed_6b.branch_pool.bn.weight.size()).to(device) )
model_6b.Mixed_6b.branch_pool.bn.bias = torch.nn.parameter.Parameter( model_6b.Mixed_6b.branch_pool.bn.bias * torch.rand(model_6b.Mixed_6b.branch_pool.bn.bias.size()).to(device) )

torch.save(model_6b, '/content/drive/MyDrive/Saliency Map Research 2023/Sensitivity/cascading_models/Pneumothorax/model_6b.pt')

# %%
#Mixed6a
model_6a = model_6b

model_6a.Mixed_6a.branch3x3.conv.weight = torch.nn.parameter.Parameter( model_6a.Mixed_6a.branch3x3.conv.weight * torch.rand(model_6a.Mixed_6a.branch3x3.conv.weight.size()).to(device) )
model_6a.Mixed_6a.branch3x3.bn.weight = torch.nn.parameter.Parameter( model_6a.Mixed_6a.branch3x3.bn.weight * torch.rand(model_6a.Mixed_6a.branch3x3.bn.weight.size()).to(device) )
model_6a.Mixed_6a.branch3x3.bn.bias = torch.nn.parameter.Parameter( model_6a.Mixed_6a.branch3x3.bn.bias * torch.rand(model_6a.Mixed_6a.branch3x3.bn.bias.size()).to(device) )

model_6a.Mixed_6a.branch3x3dbl_1.conv.weight = torch.nn.parameter.Parameter( model_6a.Mixed_6a.branch3x3dbl_1.conv.weight * torch.rand(model_6a.Mixed_6a.branch3x3dbl_1.conv.weight.size()).to(device) )
model_6a.Mixed_6a.branch3x3dbl_1.bn.weight = torch.nn.parameter.Parameter( model_6a.Mixed_6a.branch3x3dbl_1.bn.weight * torch.rand(model_6a.Mixed_6a.branch3x3dbl_1.bn.weight.size()).to(device) )
model_6a.Mixed_6a.branch3x3dbl_1.bn.bias = torch.nn.parameter.Parameter( model_6a.Mixed_6a.branch3x3dbl_1.bn.bias * torch.rand(model_6a.Mixed_6a.branch3x3dbl_1.bn.bias.size()).to(device) )

model_6a.Mixed_6a.branch3x3dbl_2.conv.weight = torch.nn.parameter.Parameter( model_6a.Mixed_6a.branch3x3dbl_2.conv.weight * torch.rand(model_6a.Mixed_6a.branch3x3dbl_2.conv.weight.size()).to(device) )
model_6a.Mixed_6a.branch3x3dbl_2.bn.weight = torch.nn.parameter.Parameter( model_6a.Mixed_6a.branch3x3dbl_2.bn.weight * torch.rand(model_6a.Mixed_6a.branch3x3dbl_2.bn.weight.size()).to(device) )
model_6a.Mixed_6a.branch3x3dbl_2.bn.bias = torch.nn.parameter.Parameter( model_6a.Mixed_6a.branch3x3dbl_2.bn.bias * torch.rand(model_6a.Mixed_6a.branch3x3dbl_2.bn.bias.size()).to(device) )

model_6a.Mixed_6a.branch3x3dbl_3.conv.weight = torch.nn.parameter.Parameter( model_6a.Mixed_6a.branch3x3dbl_3.conv.weight * torch.rand(model_6a.Mixed_6a.branch3x3dbl_3.conv.weight.size()).to(device) )
model_6a.Mixed_6a.branch3x3dbl_3.bn.weight = torch.nn.parameter.Parameter( model_6a.Mixed_6a.branch3x3dbl_3.bn.weight * torch.rand(model_6a.Mixed_6a.branch3x3dbl_3.bn.weight.size()).to(device) )
model_6a.Mixed_6a.branch3x3dbl_3.bn.bias = torch.nn.parameter.Parameter( model_6a.Mixed_6a.branch3x3dbl_3.bn.bias * torch.rand(model_6a.Mixed_6a.branch3x3dbl_3.bn.bias.size()).to(device) )

torch.save(model_6a, '/content/drive/MyDrive/Saliency Map Research 2023/Sensitivity/cascading_models/Pneumothorax/model_6a.pt')

# %%
#Mixed5d
model_5d = model_6a

model_5d.Mixed_5d.branch1x1.conv.weight = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch1x1.conv.weight * torch.rand(model_5d.Mixed_5d.branch1x1.conv.weight.size()).to(device) )
model_5d.Mixed_5d.branch1x1.bn.weight = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch1x1.bn.weight * torch.rand(model_5d.Mixed_5d.branch1x1.bn.weight.size()).to(device) )
model_5d.Mixed_5d.branch1x1.bn.bias = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch1x1.bn.bias * torch.rand(model_5d.Mixed_5d.branch1x1.bn.bias.size()).to(device) )

model_5d.Mixed_5d.branch5x5_1.conv.weight = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch5x5_1.conv.weight * torch.rand(model_5d.Mixed_5d.branch5x5_1.conv.weight.size()).to(device) )
model_5d.Mixed_5d.branch5x5_1.bn.weight = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch5x5_1.bn.weight * torch.rand(model_5d.Mixed_5d.branch5x5_1.bn.weight.size()).to(device) )
model_5d.Mixed_5d.branch5x5_1.bn.bias = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch5x5_1.bn.bias * torch.rand(model_5d.Mixed_5d.branch5x5_1.bn.bias.size()).to(device) )

model_5d.Mixed_5d.branch5x5_2.conv.weight = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch5x5_2.conv.weight * torch.rand(model_5d.Mixed_5d.branch5x5_2.conv.weight.size()).to(device) )
model_5d.Mixed_5d.branch5x5_2.bn.weight = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch5x5_2.bn.weight * torch.rand(model_5d.Mixed_5d.branch5x5_2.bn.weight.size()).to(device) )
model_5d.Mixed_5d.branch5x5_2.bn.bias = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch5x5_2.bn.bias * torch.rand(model_5d.Mixed_5d.branch5x5_2.bn.bias.size()).to(device) )

model_5d.Mixed_5d.branch3x3dbl_1.conv.weight = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch3x3dbl_1.conv.weight * torch.rand(model_5d.Mixed_5d.branch3x3dbl_1.conv.weight.size()).to(device) )
model_5d.Mixed_5d.branch3x3dbl_1.bn.weight = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch3x3dbl_1.bn.weight * torch.rand(model_5d.Mixed_5d.branch3x3dbl_1.bn.weight.size()).to(device) )
model_5d.Mixed_5d.branch3x3dbl_1.bn.bias = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch3x3dbl_1.bn.bias * torch.rand(model_5d.Mixed_5d.branch3x3dbl_1.bn.bias.size()).to(device) )

model_5d.Mixed_5d.branch3x3dbl_2.conv.weight = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch3x3dbl_2.conv.weight * torch.rand(model_5d.Mixed_5d.branch3x3dbl_2.conv.weight.size()).to(device) )
model_5d.Mixed_5d.branch3x3dbl_2.bn.weight = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch3x3dbl_2.bn.weight * torch.rand(model_5d.Mixed_5d.branch3x3dbl_2.bn.weight.size()).to(device) )
model_5d.Mixed_5d.branch3x3dbl_2.bn.bias = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch3x3dbl_2.bn.bias * torch.rand(model_5d.Mixed_5d.branch3x3dbl_2.bn.bias.size()).to(device) )

model_5d.Mixed_5d.branch3x3dbl_3.conv.weight = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch3x3dbl_3.conv.weight * torch.rand(model_5d.Mixed_5d.branch3x3dbl_3.conv.weight.size()).to(device) )
model_5d.Mixed_5d.branch3x3dbl_3.bn.weight = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch3x3dbl_3.bn.weight * torch.rand(model_5d.Mixed_5d.branch3x3dbl_3.bn.weight.size()).to(device) )
model_5d.Mixed_5d.branch3x3dbl_3.bn.bias = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch3x3dbl_3.bn.bias * torch.rand(model_5d.Mixed_5d.branch3x3dbl_3.bn.bias.size()).to(device) )

model_5d.Mixed_5d.branch_pool.conv.weight = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch_pool.conv.weight * torch.rand(model_5d.Mixed_5d.branch_pool.conv.weight.size()).to(device) )
model_5d.Mixed_5d.branch_pool.bn.weight = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch_pool.bn.weight * torch.rand(model_5d.Mixed_5d.branch_pool.bn.weight.size()).to(device) )
model_5d.Mixed_5d.branch_pool.bn.bias = torch.nn.parameter.Parameter( model_5d.Mixed_5d.branch_pool.bn.bias * torch.rand(model_5d.Mixed_5d.branch_pool.bn.bias.size()).to(device) )

torch.save(model_5d, '/content/drive/MyDrive/Saliency Map Research 2023/Sensitivity/cascading_models/Pneumothorax/model_5d.pt')

# %%
#Mixed5c
model_5c = model_5d

model_5c.Mixed_5c.branch1x1.conv.weight = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch1x1.conv.weight * torch.rand(model_5c.Mixed_5c.branch1x1.conv.weight.size()).to(device) )
model_5c.Mixed_5c.branch1x1.bn.weight = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch1x1.bn.weight * torch.rand(model_5c.Mixed_5c.branch1x1.bn.weight.size()).to(device) )
model_5c.Mixed_5c.branch1x1.bn.bias = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch1x1.bn.bias * torch.rand(model_5c.Mixed_5c.branch1x1.bn.bias.size()).to(device) )

model_5c.Mixed_5c.branch5x5_1.conv.weight = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch5x5_1.conv.weight * torch.rand(model_5c.Mixed_5c.branch5x5_1.conv.weight.size()).to(device) )
model_5c.Mixed_5c.branch5x5_1.bn.weight = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch5x5_1.bn.weight * torch.rand(model_5c.Mixed_5c.branch5x5_1.bn.weight.size()).to(device) )
model_5c.Mixed_5c.branch5x5_1.bn.bias = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch5x5_1.bn.bias * torch.rand(model_5c.Mixed_5c.branch5x5_1.bn.bias.size()).to(device) )

model_5c.Mixed_5c.branch5x5_2.conv.weight = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch5x5_2.conv.weight * torch.rand(model_5c.Mixed_5c.branch5x5_2.conv.weight.size()).to(device) )
model_5c.Mixed_5c.branch5x5_2.bn.weight = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch5x5_2.bn.weight * torch.rand(model_5c.Mixed_5c.branch5x5_2.bn.weight.size()).to(device) )
model_5c.Mixed_5c.branch5x5_2.bn.bias = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch5x5_2.bn.bias * torch.rand(model_5c.Mixed_5c.branch5x5_2.bn.bias.size()).to(device) )

model_5c.Mixed_5c.branch3x3dbl_1.conv.weight = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch3x3dbl_1.conv.weight * torch.rand(model_5c.Mixed_5c.branch3x3dbl_1.conv.weight.size()).to(device) )
model_5c.Mixed_5c.branch3x3dbl_1.bn.weight = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch3x3dbl_1.bn.weight * torch.rand(model_5c.Mixed_5c.branch3x3dbl_1.bn.weight.size()).to(device) )
model_5c.Mixed_5c.branch3x3dbl_1.bn.bias = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch3x3dbl_1.bn.bias * torch.rand(model_5c.Mixed_5c.branch3x3dbl_1.bn.bias.size()).to(device) )

model_5c.Mixed_5c.branch3x3dbl_2.conv.weight = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch3x3dbl_2.conv.weight * torch.rand(model_5c.Mixed_5c.branch3x3dbl_2.conv.weight.size()).to(device) )
model_5c.Mixed_5c.branch3x3dbl_2.bn.weight = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch3x3dbl_2.bn.weight * torch.rand(model_5c.Mixed_5c.branch3x3dbl_2.bn.weight.size()).to(device) )
model_5c.Mixed_5c.branch3x3dbl_2.bn.bias = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch3x3dbl_2.bn.bias * torch.rand(model_5c.Mixed_5c.branch3x3dbl_2.bn.bias.size()).to(device) )

model_5c.Mixed_5c.branch3x3dbl_3.conv.weight = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch3x3dbl_3.conv.weight * torch.rand(model_5c.Mixed_5c.branch3x3dbl_3.conv.weight.size()).to(device) )
model_5c.Mixed_5c.branch3x3dbl_3.bn.weight = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch3x3dbl_3.bn.weight * torch.rand(model_5c.Mixed_5c.branch3x3dbl_3.bn.weight.size()).to(device) )
model_5c.Mixed_5c.branch3x3dbl_3.bn.bias = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch3x3dbl_3.bn.bias * torch.rand(model_5c.Mixed_5c.branch3x3dbl_3.bn.bias.size()).to(device) )

model_5c.Mixed_5c.branch_pool.conv.weight = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch_pool.conv.weight * torch.rand(model_5c.Mixed_5c.branch_pool.conv.weight.size()).to(device) )
model_5c.Mixed_5c.branch_pool.bn.weight = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch_pool.bn.weight * torch.rand(model_5c.Mixed_5c.branch_pool.bn.weight.size()).to(device) )
model_5c.Mixed_5c.branch_pool.bn.bias = torch.nn.parameter.Parameter( model_5c.Mixed_5c.branch_pool.bn.bias * torch.rand(model_5c.Mixed_5c.branch_pool.bn.bias.size()).to(device) )

torch.save(model_5c, '/content/drive/MyDrive/Saliency Map Research 2023/Sensitivity/cascading_models/Pneumothorax/model_5c.pt')

# %%
#Mixed5b
model_5b = model_5c

model_5b.Mixed_5b.branch1x1.conv.weight = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch1x1.conv.weight * torch.rand(model_5b.Mixed_5b.branch1x1.conv.weight.size()).to(device) )
model_5b.Mixed_5b.branch1x1.bn.weight = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch1x1.bn.weight * torch.rand(model_5b.Mixed_5b.branch1x1.bn.weight.size()).to(device) )
model_5b.Mixed_5b.branch1x1.bn.bias = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch1x1.bn.bias * torch.rand(model_5b.Mixed_5b.branch1x1.bn.bias.size()).to(device) )

model_5b.Mixed_5b.branch5x5_1.conv.weight = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch5x5_1.conv.weight * torch.rand(model_5b.Mixed_5b.branch5x5_1.conv.weight.size()).to(device) )
model_5b.Mixed_5b.branch5x5_1.bn.weight = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch5x5_1.bn.weight * torch.rand(model_5b.Mixed_5b.branch5x5_1.bn.weight.size()).to(device) )
model_5b.Mixed_5b.branch5x5_1.bn.bias = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch5x5_1.bn.bias * torch.rand(model_5b.Mixed_5b.branch5x5_1.bn.bias.size()).to(device) )

model_5b.Mixed_5b.branch5x5_2.conv.weight = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch5x5_2.conv.weight * torch.rand(model_5b.Mixed_5b.branch5x5_2.conv.weight.size()).to(device) )
model_5b.Mixed_5b.branch5x5_2.bn.weight = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch5x5_2.bn.weight * torch.rand(model_5b.Mixed_5b.branch5x5_2.bn.weight.size()).to(device) )
model_5b.Mixed_5b.branch5x5_2.bn.bias = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch5x5_2.bn.bias * torch.rand(model_5b.Mixed_5b.branch5x5_2.bn.bias.size()).to(device) )

model_5b.Mixed_5b.branch3x3dbl_1.conv.weight = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch3x3dbl_1.conv.weight * torch.rand(model_5b.Mixed_5b.branch3x3dbl_1.conv.weight.size()).to(device) )
model_5b.Mixed_5b.branch3x3dbl_1.bn.weight = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch3x3dbl_1.bn.weight * torch.rand(model_5b.Mixed_5b.branch3x3dbl_1.bn.weight.size()).to(device) )
model_5b.Mixed_5b.branch3x3dbl_1.bn.bias = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch3x3dbl_1.bn.bias * torch.rand(model_5b.Mixed_5b.branch3x3dbl_1.bn.bias.size()).to(device) )

model_5b.Mixed_5b.branch3x3dbl_2.conv.weight = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch3x3dbl_2.conv.weight * torch.rand(model_5b.Mixed_5b.branch3x3dbl_2.conv.weight.size()).to(device) )
model_5b.Mixed_5b.branch3x3dbl_2.bn.weight = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch3x3dbl_2.bn.weight * torch.rand(model_5b.Mixed_5b.branch3x3dbl_2.bn.weight.size()).to(device) )
model_5b.Mixed_5b.branch3x3dbl_2.bn.bias = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch3x3dbl_2.bn.bias * torch.rand(model_5b.Mixed_5b.branch3x3dbl_2.bn.bias.size()).to(device) )

model_5b.Mixed_5b.branch3x3dbl_3.conv.weight = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch3x3dbl_3.conv.weight * torch.rand(model_5b.Mixed_5b.branch3x3dbl_3.conv.weight.size()).to(device) )
model_5b.Mixed_5b.branch3x3dbl_3.bn.weight = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch3x3dbl_3.bn.weight * torch.rand(model_5b.Mixed_5b.branch3x3dbl_3.bn.weight.size()).to(device) )
model_5b.Mixed_5b.branch3x3dbl_3.bn.bias = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch3x3dbl_3.bn.bias * torch.rand(model_5b.Mixed_5b.branch3x3dbl_3.bn.bias.size()).to(device) )

model_5b.Mixed_5b.branch_pool.conv.weight = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch_pool.conv.weight * torch.rand(model_5b.Mixed_5b.branch_pool.conv.weight.size()).to(device) )
model_5b.Mixed_5b.branch_pool.bn.weight = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch_pool.bn.weight * torch.rand(model_5b.Mixed_5b.branch_pool.bn.weight.size()).to(device) )
model_5b.Mixed_5b.branch_pool.bn.bias = torch.nn.parameter.Parameter( model_5b.Mixed_5b.branch_pool.bn.bias * torch.rand(model_5b.Mixed_5b.branch_pool.bn.bias.size()).to(device) )

torch.save(model_5b, '/content/drive/MyDrive/Saliency Map Research 2023/Sensitivity/cascading_models/Pneumothorax/model_5b.pt')
